# %%
import re

# %%
logText = open(r'.\logs\2. left handpiece - long cable - clutch pulled when hand present.log', 'r').read()
pattern = r"ProcessCapacitivePads\(\).{10}(\d+\.\d+).+(\d+\.\d+).+(\d+\.\d+).+(\d+\.\d+)"
p = re.compile(pattern)
result = ''
for line in logText.splitlines(1):
    match = p.search(logText)
    logText = logText.split('\n',2)[-1]
    result += str(match.group(1,2,3,4) if match else '').replace("'", "").replace(r")", "").replace(r"(", "") + '\n'
result = result.strip()

# %%
print(result)
# Out:
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# 3.02, 2.94, 1.55, 1.91
# ...
